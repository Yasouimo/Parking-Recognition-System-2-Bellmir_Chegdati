# %% [markdown]
# # Parking Detection model using Yolo v8
#
# **u can find the data i used for training and the results in the link here**
# https://drive.google.com/drive/folders/1pjkx1eXgyv80Cqmq4GyBHDkimZCppjj2?usp=drive_link

# %% [markdown]
# # Importing and Downloading

# %%
#set up google drive to access our data
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/Parking detection/Custom Dataset.zip" -d "/content/drive/MyDrive/Parking detection/"
# Out:
# Archive:  /content/drive/MyDrive/Parking detection/Custom Dataset.zip
#    creating: /content/drive/MyDrive/Parking detection/test/
#    creating: /content/drive/MyDrive/Parking detection/test/images/
#   inflating: /content/drive/MyDrive/Parking detection/test/images/2022-11-15-14-09-20_mp4-38_jpg.rf.3a5808ed7f30028db64e9c2423304a64.jpg
#   inflating: /content/drive/MyDrive/Parking detection/test/images/2022-11-15-14-11-26_mp4-37_jpg.rf.a368384b115412a38ec594eb9a0c172f.jpg
#   inflating: /content/drive/MyDrive/Parking detection/test/images/4k-time-lapse-car-parking-lot-stock-video-download-video-clip-now-istock_TyROSAGZ_mp4-117_jpg.rf.96abf782a7cb9561b17c06a8442b2f3e.jpg
#   inflating: /content/drive/MyDrive/Parking detection/test/images/4k-time-lapse-car-parking-lot-stock-video-download-video-clip-now-istock_TyROSAGZ_mp4-137_jpg.rf.afc6730f9dbfb65e3b7c5112cdc3b00a.jpg
# ...

# %%
#install and import ultralytics
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.36 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.9/112.6 GB disk)

# %%
#install supervision
# !pip install supervision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 3.9 MB/s eta 0:00:00
# ...

# %%
#import a pretrained YOLO model
import os
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

from IPython.display import display, Image
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 78.6MB/s]

# %% [markdown]
# # Model Training

# %%
# !pip install -U jax jaxlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 26.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.3/87.3 MB 9.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.4.33
#     Uninstalling jaxlib-0.4.33:
#       Successfully uninstalled jaxlib-0.4.33
#   Attempting uninstall: jax
#     Found existing installation: jax 0.4.33
#     Uninstalling jax-0.4.33:
#       Successfully uninstalled jax-0.4.33
# ...

# %%
from jax.tree_util import tree_unflatten

# %%
# prompt: results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=100)  #train the model.
# results = model.val()  #evaluate model performance on the validation set
# fix this code to solve the probs
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-143babd4c950> in <cell line: 1>()
# ----> 1 results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=100)  #train the model.
#       2 results = model.val()  #evaluate model performance on the validation set
# NameError: name 'ROOT_DIR' is not defined
# there is data.yaml here
# path: '/content/drive/MyDrive/Parking detection'
# train: train/images
# val: val/images
# test: test/images
# names:
#   0: empty
#   1: occupied

ROOT_DIR = "/content/drive/MyDrive/Parking detection" # Define ROOT_DIR
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=100)  #train the model.
results = model.val()  #evaluate model performance on the validation set
# Out:
# Ultralytics 8.3.36 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# prompt: /content/runs
# copy this please to /content/drive/MyDrive/Parking detection
# move it or copy it put it there please

# Define source and destination paths
source = '/content/runs'
destination = '/content/drive/MyDrive/Parking detection/runs' #added /runs to the destination path

# Use shutil to copy the directory with the dirs_exist_ok parameter
shutil.copytree(source, destination, dirs_exist_ok=True)
# Out:
# '/content/drive/MyDrive/Parking detection/runs'

# %% [markdown]
# # Testing
